# %% [markdown]
# hey ganesh

# %%
print("ganesh")
# Out:
# ganesh

# %%
age = 18

if age >= 18:
    print("You are an adult.")
else:
    print("You are under 18.")
# Out:
# You are an adult.

# %% [markdown]
# addition program

# %%
a = 5
b = 3
answer = a + b
print("Answer:", answer)
# Out:
# Answer: 8
