# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshingle9552/118/blob/main/TitanicDataAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import numpy as np

# %%
tdata=pd.read_csv("Titanic-Dataset.csv")

# %%
tdata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tdata.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
tdata.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
tdata.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
tdata.boxplot(['Survived'])
# Out:
# <Axes: >

# %%
tdata.boxplot(['Age'])
# Out:
# <Axes: >

# %%
tdata.plot('Survived','Age')
# Out:
# <Axes: xlabel='Survived'>

# %%
tdata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.countplot(x='Survived',data=tdata)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Sex',data=tdata)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Survived',hue='Pclass',data=tdata)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
tdata['Age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
tdata['Fare'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.countplot(x='SibSp',data=tdata)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # Data Wrangling

# %%
tdata.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
tdata.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(tdata.isnull())
# Out:
# <Axes: >

# %%
sns.boxplot(x='Pclass',y='Age',data=tdata)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
tdata.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
tdata.drop('Cabin',axis=1, inplace=True)

# %%
tdata.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
tdata.dropna(inplace=True)

# %%
sns.heatmap(tdata.isnull(),yticklabels=False,cbar=False)
# Out:
# <Axes: >

# %%
tdata.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# # Convert Categorical data in to some dummy numerical variables

# %%
pd.get_dummies(tdata['Sex'])
# Out:
#      female   male
# 0     False   True
# 1      True  False
# 2      True  False
# 3      True  False
# 4     False   True
# ..      ...    ...
# 885    True  False
# 886   False   True
# 887    True  False
# 889   False   True
# 890   False   True
#
# [712 rows x 2 columns]

# %%
sex=pd.get_dummies(tdata['Sex'],drop_first=True)

# %%
sex
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 885  False
# 886   True
# 887  False
# 889   True
# 890   True
#
# [712 rows x 1 columns]

# %%
pd.get_dummies(tdata['Embarked'])
# Out:
#          C      Q      S
# 0    False  False   True
# 1     True  False  False
# 2    False  False   True
# 3    False  False   True
# 4    False  False   True
# ..     ...    ...    ...
# 885  False   True  False
# 886  False  False   True
# 887  False  False   True
# 889   True  False  False
# 890  False   True  False
#
# [712 rows x 3 columns]

# %%
embark=pd.get_dummies(tdata['Embarked'],drop_first=True)

# %%
embark
# Out:
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 885   True  False
# 886  False   True
# 887  False   True
# 889  False  False
# 890   True  False
#
# [712 rows x 2 columns]

# %%
pcl=pd.get_dummies(tdata['Pclass'],drop_first=True)

# %%
pcl
# Out:
#          2      3
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False  False
# 4    False   True
# ..     ...    ...
# 885  False   True
# 886   True  False
# 887  False  False
# 889  False  False
# 890  False   True
#
# [712 rows x 2 columns]

# %%
titanicdata=pd.concat([tdata,sex,embark,pcl],axis=1)

# %%
titanicdata.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked   male      Q      S      2  \
# 0      0         A/5 21171   7.2500        S   True  False   True  False
# 1      0          PC 17599  71.2833        C  False  False  False  False
# 2      0  STON/O2. 3101282   7.9250        S  False  False   True  False
# ...

# %%
titanicdata
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanicdata.drop(['Sex','Embarked','Name','Ticket','Pclass'],axis=1,inplace=True)

# %%
titanicdata
# Out:
#      PassengerId  Survived   Age  SibSp  Parch     Fare   male      Q      S  \
# 0              1         0  22.0      1      0   7.2500   True  False   True
# 1              2         1  38.0      1      0  71.2833  False  False  False
# 2              3         1  26.0      0      0   7.9250  False  False   True
# 3              4         1  35.0      1      0  53.1000  False  False   True
# 4              5         0  35.0      0      0   8.0500   True  False   True
# ..           ...       ...   ...    ...    ...      ...    ...    ...    ...
# 885          886         0  39.0      0      5  29.1250  False   True  False
# 886          887         0  27.0      0      0  13.0000   True  False   True
# 887          888         1  19.0      0      0  30.0000  False  False   True
# 889          890         1  26.0      0      0  30.0000   True  False  False
# 890          891         0  32.0      0      0   7.7500   True   True  False
#
#          2      3
# 0    False   True
# ...

# %% [markdown]
# # Apply Sklearn

# %% [markdown]
# # Train and Test data

# %%
X=titanicdata.drop('Survived',axis=1)
y=titanicdata['Survived']

# %%
X
# Out:
#      PassengerId   Age  SibSp  Parch     Fare   male      Q      S      2  \
# 0              1  22.0      1      0   7.2500   True  False   True  False
# 1              2  38.0      1      0  71.2833  False  False  False  False
# 2              3  26.0      0      0   7.9250  False  False   True  False
# 3              4  35.0      1      0  53.1000  False  False   True  False
# 4              5  35.0      0      0   8.0500   True  False   True  False
# ..           ...   ...    ...    ...      ...    ...    ...    ...    ...
# 885          886  39.0      0      5  29.1250  False   True  False  False
# 886          887  27.0      0      0  13.0000   True  False   True   True
# 887          888  19.0      0      0  30.0000  False  False   True  False
# 889          890  26.0      0      0  30.0000   True  False  False  False
# 890          891  32.0      0      0   7.7500   True   True  False  False
#
#          3
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# ...

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 712, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 712, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.30,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=1000)
X_train.columns = X_train.columns.astype(str)
X_test.columns = X_test.columns.astype(str)
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.83      0.82       126
#            1       0.75      0.72      0.73        88
#
#     accuracy                           0.79       214
#    macro avg       0.78      0.77      0.78       214
# weighted avg       0.78      0.79      0.78       214

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,predictions)
# Out:
# array([[105,  21],
#        [ 25,  63]])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,predictions)*100
# Out:
# 78.50467289719626
